# %% [markdown]
# ### 1. Import the dataSet

# %%
import requests

headers = {"Flic-Token": "flic_6e2d8d25dc29a4ddd382c2383a903cf4a688d1a117f6eb43b35a1e7fadbb84b8"}
url = "https://api.socialverseapp.com/posts/view?page=1&page_size=1000"
response = requests.get(url, headers=headers)
data = response.json()

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\debasish das\.conda\envs\env1\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\debasish das\.conda\envs\env1\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\debasish das\.conda\envs\env1\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\debasish das\.conda\envs\env1\lib\site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\debasish das\.conda\envs\env1\lib\site-packages (from requests) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head(4)
# Out:
#     status                            message  page  page_size  max_page_size  \
# 0  success  Viewed posts fetched successfully     1        145           1000
# 1  success  Viewed posts fetched successfully     1        145           1000
# 2  success  Viewed posts fetched successfully     1        145           1000
# 3  success  Viewed posts fetched successfully     1        145           1000
#
#                                                posts
# 0  {'id': 1391, 'category': {'id': 8, 'name': 'Bl...
# 1  {'id': 1390, 'category': {'id': 8, 'name': 'Bl...
# 2  {'id': 996, 'category': {'id': 6, 'name': 'Ins...
# 3  {'id': 654, 'category': {'id': 2, 'name': 'Vib...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   status         145 non-null    object
#  1   message        145 non-null    object
#  2   page           145 non-null    int64
#  3   page_size      145 non-null    int64
#  4   max_page_size  145 non-null    int64
#  5   posts          145 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 6.9+ KB

# %%
df["status"].value_counts()
# Out:
# status
# success    145
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         page  page_size  max_page_size
# count  145.0      145.0          145.0
# mean     1.0      145.0         1000.0
# std      0.0        0.0            0.0
# min      1.0      145.0         1000.0
# 25%      1.0      145.0         1000.0
# 50%      1.0      145.0         1000.0
# 75%      1.0      145.0         1000.0
# max      1.0      145.0         1000.0

# %%
df["posts"][1]
# Out:
# {'id': 1390,
#  'category': {'id': 8,
#   'name': 'Bloom Scroll',
#   'count': 55,
#   'description': 'Scroll until you bloom',
#   'image_url': 'https://socialverse-assets.s3.us-east-1.amazonaws.com/categories/Icon+with+BG.png'},
#  'slug': 'ede97335202739bd34f8d7485eedc015b33b375c',
#  'title': 'Sometimes letting things go is an act of far greater power than defending or hanging on.” - Eckhart Tolle\n\nWhen was the last time letting go felt more powerful than holding on? ✨',
#  'identifier': '89MbMZ7',
#  'comment_count': 0,
#  'upvote_count': 0,
#  'view_count': 22,
#  'exit_count': 469,
#  'rating_count': 2,
#  'average_rating': 51,
#  'share_count': 0,
#  'video_link': 'https://video-cdn.socialverseapp.com/bloomscroller_022c743b-d30f-47c3-82f9-c0a8f9893557.mp4',
#  'contract_address': '',
#  'chain_id': '',
#  'chart_url': '',
#  'baseToken': {'address': '', 'name': '', 'symbol': '', 'image_url': ''},
#  'is_locked': False,
#  'created_at': 1733381498000,
#  'first_name': 'Grace',
#  'last_name': 'Matelich',
#  'username': 'bloomscroller',
#  'upvoted': False,
#  'bookmarked': False,
#  'thumbnail_url': 'https://video-cdn.socialverseapp.com/bloomscroller_022c743b-d30f-47c3-82f9-c0a8f9893557.0000002.jpg',
#  'gif_thumbnail_url': 'https://video-cdn.socialverseapp.com/bloomscroller_022c743b-d30f-47c3-82f9-c0a8f9893557.gif',
#  'following': True,
#  'picture_url': 'https://assets.socialverseapp.com/profile/7.png',
#  'post_summary': []}

# %% [markdown]
# ## 2 Creating New Dataframe

# %%
new_df=pd.json_normalize(df["posts"])

# %%
new_df.sample(4)
# Out:
#        id                                      slug  \
# 82   1291  2695583f3ad45edf8852029af9ca761a5f38105e
# 105  1296  7f66b513d61e2aeedc1091bf47d0b9830dbec2ed
# 127  1256  6a11df5f5516244bf10983ca883b48e622dcbe3b
# 115  1263  e061ee4db3aef083e7edc9b8a6f9a37fbb008f98
#
#                                                  title identifier  \
# 82         Can Moo Deng’s MEME COIN GO HIGHER_ #shorts    ajMOQkc
# 105  One Dollar and a Dream series (lost $$$ in sec...    6rx5G94
# 127  Memecoins are wild! #trading #crypto #sol #sol...    PjsLKLn
# 115  Trading memecoins in 2024 ____ $DUKO ON SOLANA...    4KY_R0R
#
#      comment_count  upvote_count  view_count  exit_count  rating_count  \
# 82               0             4          84          17             5
# 105              0             2          39           9             2
# 127              0            49         101          61             3
# 115              0            57         103         209            15
#
#      average_rating  ...  post_summary category.id category.name  \
# 82               20  ...            []          22        SolTok
# 105              18  ...            []          22        SolTok
# 127              18  ...            []          22        SolTok
# 115              15  ...            []          22        SolTok
#
#     category.count                 category.description  \
# 82              51  Ride the wave of Solana with SolTok
# 105             51  Ride the wave of Solana with SolTok
# 127             51  Ride the wave of Solana with SolTok
# 115             51  Ride the wave of Solana with SolTok
#
#                                category.image_url  \
# 82   https://assets.socialverseapp.com/soltok.png
# 105  https://assets.socialverseapp.com/soltok.png
# 127  https://assets.socialverseapp.com/soltok.png
# 115  https://assets.socialverseapp.com/soltok.png
#
#                                 baseToken.address   baseToken.name  \
# 82   ED5nyyWEzpPPiWimP8vYm7sD7TD3LAt3Q3gRTWHzPJBY         Moo Deng
# 105  8AGrudQDbjNjnHzBsrndfVDBHgg6KBJ7RN6j3hbfq3Qh  degen the otter
# 127  43DCU6q6YQr9R8ymqoKvuAfGQdn83BcmJooiHoBzrg4B         DogeCoin
# 115  HLptm5e6rTgh4EKgDpYFrnRHbjpkMyVdEeREEa2G7rf9             Duko
#
#     baseToken.symbol                                baseToken.image_url
# 82           MOODENG  https://dd.dexscreener.com/ds-data/tokens/sola...
# 105            degen  https://dd.dexscreener.com/ds-data/tokens/sola...
# 127             DOGE  https://dd.dexscreener.com/ds-data/tokens/sola...
# 115             DUKO  https://dd.dexscreener.com/ds-data/tokens/sola...
#
# [4 rows x 36 columns]

# %%
new_df.columns
# Out:
# Index(['id', 'slug', 'title', 'identifier', 'comment_count', 'upvote_count',
#        'view_count', 'exit_count', 'rating_count', 'average_rating',
#        'share_count', 'video_link', 'contract_address', 'chain_id',
#        'chart_url', 'is_locked', 'created_at', 'first_name', 'last_name',
#        'username', 'upvoted', 'bookmarked', 'thumbnail_url',
#        'gif_thumbnail_url', 'following', 'picture_url', 'post_summary',
#        'category.id', 'category.name', 'category.count',
#        'category.description', 'category.image_url', 'baseToken.address',
#        'baseToken.name', 'baseToken.symbol', 'baseToken.image_url'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# Combine relevant text-based columns into a single feature
new_df["combined_features"] = (
    new_df["title"] + " " +
    new_df["category.name"] + " " +
    new_df["category.description"]
)

# TF-IDF Vectorization
tfidf = TfidfVectorizer(stop_words="english")
tfidf_matrix = tfidf.fit_transform(new_df["combined_features"])

# Compute Cosine Similarity
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Function to recommend videos
def recommend_content_based(video_id, cosine_sim, posts_df):
    idx = posts_df[posts_df["id"] == video_id].index[0]
    similarity_scores = list(enumerate(cosine_sim[idx]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similar_videos = [posts_df.iloc[i[0]][["title","video_link","category.image_url"]] for i in similarity_scores[0:6]]
    return similar_videos

# Example Recommendation
video_id = 1242
recommended_videos = recommend_content_based(video_id, cosine_sim, new_df)
print("Recommended Videos:", recommended_videos)
# Out:
# Recommended Videos: [title                 Am I traumitized_ #dailyinspiration #wisdom #m...
# video_link            https://video-cdn.socialverseapp.com/kinha_19f...
# category.image_url    https://assets.socialverseapp.com/categories/a...
# Name: 142, dtype: object, title                 Hope… sometimes its all we have. #wisdom #moti...
# video_link            https://video-cdn.socialverseapp.com/kinha_1a8...
# category.image_url    https://assets.socialverseapp.com/categories/a...
# Name: 139, dtype: object, title                 Mind coloring… never thought of it that way. #...
# video_link            https://video-cdn.socialverseapp.com/kinha_5b4...
# category.image_url    https://assets.socialverseapp.com/categories/a...
# Name: 116, dtype: object, title
# video_link            https://video-cdn.socialverseapp.com/kinha_45e...
# category.image_url    https://assets.socialverseapp.com/categories/a...
# Name: 42, dtype: object, title
# video_link            https://video-cdn.socialverseapp.com/kinha_e79...
# category.image_url    https://assets.socialverseapp.com/categories/a...
# Name: 43, dtype: object, title
# video_link            https://video-cdn.socialverseapp.com/kinha_977...
# category.image_url    https://assets.socialverseapp.com/categories/a...
# Name: 46, dtype: object]

# %%
from sklearn.decomposition import TruncatedSVD
import numpy as np

# Create a User-Item Interaction Matrix
user_item_matrix = new_df.pivot_table(index="username", columns="id", values="view_count", fill_value=0)

# Apply SVD
svd = TruncatedSVD(n_components=10)
user_factors = svd.fit_transform(user_item_matrix)
item_factors = svd.components_

# Function to recommend based on SVD
def recommend_collaborative(user, user_item_matrix, user_factors, item_factors):
    user_idx = user_item_matrix.index.get_loc(user)
    user_vector = user_factors[user_idx]
    scores = np.dot(user_vector, item_factors)
    top_item_indices = np.argsort(scores)[::-1][:5]
    return user_item_matrix.columns[top_item_indices]

# Example Recommendation
user = "bloomscroller"
recommended_videos = recommend_collaborative(user, user_item_matrix, user_factors, item_factors)
print("Recommended Videos:", recommended_videos)
# Out:
# Recommended Videos: Index([1384, 1385, 1381, 1380, 1390], dtype='int64', name='id')

# %%
def recommend_hybrid(user, user_item_matrix, user_factors, item_factors, cosine_sim, posts_df):
    if user in user_item_matrix.index:  # Collaborative Filtering
        return recommend_collaborative(user, user_item_matrix, user_factors, item_factors)
    else:  # Content-Based Filtering (Cold Start)
        most_viewed_video_id = posts_df.loc[posts_df["view_count"].idxmax()]["id"]
        return recommend_content_based(most_viewed_video_id, cosine_sim, posts_df)

# Example Hybrid Recommendation
user = "new_user"  # Replace with an actual user or a new user
recommended_videos = recommend_hybrid(user, user_item_matrix, user_factors, item_factors, cosine_sim, new_df)
print("Recommended Videos:", recommended_videos)
# Out:
# Recommended Videos: [title                                            What is DAI Stablecoin
# video_link            https://video-cdn.socialverseapp.com/kinha_704...
# category.image_url    https://assets.socialverseapp.com/categories/m...
# Name: 111, dtype: object, title                 Top 3 #dogwithat #memecoins for the #bullmarke...
# video_link            https://video-cdn.socialverseapp.com/kinha_25c...
# category.image_url    https://assets.socialverseapp.com/categories/m...
# Name: 75, dtype: object, title                 Brett the meme topken #memecoins for the #bull...
# video_link            https://video-cdn.socialverseapp.com/kinha_13a...
# category.image_url    https://assets.socialverseapp.com/categories/m...
# Name: 110, dtype: object, title                 Spiritual ego 👀. You can’t be in a good, “high...
# video_link            https://video-cdn.socialverseapp.com/bloomscro...
# category.image_url    https://socialverse-assets.s3.us-east-1.amazon...
# Name: 0, dtype: object, title                 Sometimes letting things go is an act of far g...
# video_link            https://video-cdn.socialverseapp.com/bloomscro...
# category.image_url    https://socialverse-assets.s3.us-east-1.amazon...
# Name: 1, dtype: object, title                                Ram Siya Ram Siya Ram Jai Jai Ram❤
# video_link            https://video-cdn.socialverseapp.com/kinha_4ce...
# category.image_url    https://assets.socialverseapp.com/categories/7...
# Name: 2, dtype: object]

# %%
import pandas as pd
import logging
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import numpy as np
from pathlib import Path
import json

# Set up logging
Path("logs").mkdir(exist_ok=True)
logging.basicConfig(
    filename="logs/recomendation.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
)


# Define function to load data
def load_data(file_path):
    try:
        data = pd.read_csv(file_path)
        logging.info(f"Data loaded successfully from {file_path}")
        return data
    except Exception as e:
        logging.error(f"Error loading data from {file_path}: {e}")
        return None

# Define function to preprocess data
def preprocess_data(merged_data):
    try:
        # Convert relevant columns to numeric, forcing errors to NaN
        merged_data['comment_count'] = pd.to_numeric(merged_data['comment_count'], errors='coerce').fillna(0)
        merged_data['upvote_count'] = pd.to_numeric(merged_data['upvote_count'], errors='coerce').fillna(0)
        merged_data['view_count'] = pd.to_numeric(merged_data['view_count'], errors='coerce').fillna(0)
        merged_data['share_count_x'] = pd.to_numeric(merged_data['share_count_x'], errors='coerce').fillna(0)

        # Calculate engagement score
        merged_data['engagement_score'] = (
            merged_data['comment_count'] +
            merged_data['upvote_count'] +
            merged_data['view_count'] +
            merged_data['share_count_x']
        )

        # Ensure all text columns are strings before concatenation
        merged_data['title'] = merged_data['title'].astype(str)
        merged_data['bio'] = merged_data['bio'].astype(str)
        merged_data['category.name'] = merged_data['category.name'].astype(str)
        merged_data['category.description'] = merged_data['category.description'].astype(str)
  

        # Combine text-based columns to create a metadata summary for the content
        merged_data['metadata'] = (
            merged_data['title'] + ' ' +
            merged_data['bio'] + ' ' +
            merged_data['category.name'] + ' ' +
            merged_data['category.description']
        )
        logging.info("Data preprocessing completed successfully.")
    except Exception as e:
        logging.error(f"Error during data preprocessing: {e}")

# Define function for TF-IDF vectorization
def compute_cosine_similarity(merged_data):
    try:
        tfidf = TfidfVectorizer(stop_words="english")
        tfidf_matrix = tfidf.fit_transform(merged_data["metadata"])
        cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
        logging.info("Cosine similarity computed successfully.")
        return cosine_sim
    except Exception as e:
        logging.error(f"Error during TF-IDF vectorization or cosine similarity computation: {e}")
        return None

# Function to recommend content based on similarity
def recommend_content_based(video_id, cosine_sim, posts_df):
    try:
        idx = posts_df[posts_df["id"] == video_id].index[0]
        similarity_scores = list(enumerate(cosine_sim[idx]))
        similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
        similar_videos = [posts_df.iloc[i[0]]["video_link"] for i in similarity_scores[0:6]]
        return similar_videos
    except Exception as e:
        logging.error(f"Error in recommend_content_based: {e}")
        return []

# Define function for collaborative filtering
def recommend_collaborative(user, user_item_matrix, user_factors, item_factors, df):
    try:
        user_idx = user_item_matrix.index.get_loc(user)
        user_vector = user_factors[user_idx]
        scores = np.dot(user_vector, item_factors)
        top_item_indices = np.argsort(scores)[::-1][:5]
        ids = user_item_matrix.columns[top_item_indices]
        recommendations = df[df["id"].isin(ids)]
        return recommendations[["username", "id", "title", "video_link", "engagement_score"]].to_dict(orient="records")
    except Exception as e:
        logging.error(f"Error in recommend_collaborative: {e}")
        return []

# Define function for new user recommendations 
def recommend_new_user_videos(merged_data):
    try:
        top_categories = (
            merged_data.groupby("category.name")["view_count"]
            .sum()
            .sort_values(ascending=False)
            .head(6)
            .index
        )

        category_recommendations = (
            merged_data[merged_data["category.name"].isin(top_categories)]
            .sort_values(by="view_count", ascending=False)
            .head(6)
        )

        top_rated_videos = (
            merged_data.sort_values(by="average_rating", ascending=False)
            .head(6)
        )

        most_commented_videos = (
            merged_data.sort_values(by="comment_count", ascending=False)
            .head(6)
        )

        top_viewed_videos = (
            merged_data.sort_values(by="view_count", ascending=False)
            .head(6)
        )

        recommendations = pd.concat(
            [category_recommendations, top_rated_videos, most_commented_videos, top_viewed_videos]
        ).drop_duplicates(subset="id")

        return recommendations[["id", "title", "category.name", "video_link", "view_count", "average_rating", "comment_count"]].sample(5).to_dict(orient="records")
    except Exception as e:
        logging.error(f"Error in recommend_new_user_videos: {e}")
        return []

# Define hybrid recommendation function
def recommend_hybrid(user, user_item_matrix, user_factors, item_factors, cosine_sim, posts_df):
    try:
        if user in user_item_matrix.index:
            content = recommend_collaborative(user, user_item_matrix, user_factors, item_factors, posts_df)
            print("Content-Based Recommendations:", content[:5].to_dict())
            user_based = recommend_collaborative(user, user_item_matrix, user_factors, item_factors, posts_df)
            print("Collaborative Recommendations:", user[:5].to_dict())
            recommendation = pd.concat([content, user_based])
            return recommendation.to_dict(orient="records")
        else:
            x=recommend_new_user_videos(posts_df)
            print("Recommendations for New Users:", x[:5])
            return x
    except Exception as e:
        logging.error(f"Error in recommend_hybrid: {e}")
        return []

# Main script
merged_data = load_data(r"C:\Users\Debasish Das\Desktop\Internship Project\Hybrid_rccomendation_System\data\preprocessed\merged_data.csv")
if merged_data is not None:
    preprocess_data(merged_data)
    cosine_sim = compute_cosine_similarity(merged_data)

    # Create a User-Item Interaction Matrix
    user_item_matrix = merged_data.pivot_table(index="id", columns="username", values="engagement_score", fill_value=0)
    
    # Apply SVD
    svd = TruncatedSVD(n_components=10)
    user_factors = svd.fit_transform(user_item_matrix)
    item_factors = svd.components_

    user = ""  # Test with a new user
    recommended_videos = recommend_hybrid(user, user_item_matrix, user_factors, item_factors, cosine_sim, merged_data)
    k=pd.DataFrame(recommended_videos)
    
    with open('recommendations.json', 'w') as file:
        json.dump(recommended_videos, file, indent=4)
